# %% [markdown]
# ## Título 1
# Isto é um texto em formato markdown

# %% [markdown]
# ### Comando mardown e shortcuts
#
# Shift + Enter = roda a célula e insere outra abaixo
#
# x = apaga a celula marcada
#
# b = insere uma célula abaixo

# %% [markdown]
# # 1.Python starter

# %% [markdown]
# ## 1.1. Manipulação de números

# %% [markdown]
# Adição

# %%
2 + 3
# Out:
# 5

# %% [markdown]
# Subtração

# %%
2 - 1
# Out:
# 1

# %% [markdown]
# Multiplicação

# %%
2 * 2
# Out:
# 4

# %% [markdown]
# Divisão

# %%
2 / 2
# Out:
# 1.0

# %% [markdown]
# Potenciação

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# Raiz quadrada

# %%
9 ** (1/2)
# Out:
# 3.0

# %% [markdown]
# Operações em cadeia

# %%
2 * 2 + 3 - 4 / 2
# Out:
# 5.0

# %% [markdown]
# ## 1.2. Variáveis

# %%
variavel_um = 5

# %%
variavel_dois = 2

# %%
variavel_um + 2
# Out:
# 7

# %%
variavel_um + variavel_dois
# Out:
# 7

# %%
variavel_dois = variavel_dois ** 2
print(variavel_dois)
# Out:
# 16

# %% [markdown]
# ## 1.3. Strings e indexação (falta ver essa aula)

# %%
string = "hello"

# %%
print("Concatenação de string, hello + a:")
string + "a"
# Out:
# Concatenação de string, hello + a:
# 'helloa'

# %%
print("Mostra o tipo da variável")
type("a")
# Out:
# Mostra o tipo da variável
# str

# %%
print("Mostra o tamanho da variável")
len(string)
# Out:
# Mostra o tamanho da variável
# 5

# %% [markdown]
# ## 1.4. Métodos embutidos da string

# %%
dir("hello")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
"HEllo".lower()
# Out:
# 'hello'

# %%
"hello".upper()
# Out:
# 'HELLO'

# %%
"hello Rodrigo".split(" ")
# Out:
# ['hello', 'Rodrigo']

# %%
age = 10
weight = 50
"A idade da pessoa é {} anos e ela pesa {} quilos.".format(age, weight)
# Out:
# 'A idade da pessoa é 10 anos e ela pesa 50 quilos.'

# %% [markdown]
# ## 1.5. Listas

# %% [markdown]
# ### 1.5.1. Intrdução à listas

# %%
minha_lista = [1, 2, "mari"]

# %%
type(minha_lista)
# Out:
# list

# %%
minha_lista[-1]
# Out:
# 'mari'

# %%
minha_lista[1]
# Out:
# 2

# %%
minha_lista[1:-1]
# Out:
# [2]

# %%
minha_lista
# Out:
# [1, 2, 'mari']

# %%
minha_lista = [1, 2, 3, 6, ["mari", 2, "luis"]]

# %%
minha_lista[1]
# Out:
# 2

# %%
minha_lista[4]
# Out:
# ['mari', 2, 'luis']

# %%
minha_lista[4][2]
# Out:
# 'luis'

# %%
minha_lista[2:]
# Out:
# [3, 6, ['mari', 2, 'luis']]

# %% [markdown]
# ### 1.5.2. Méttodos básicos de listas

# %%
x = [1, 2, 3]

# %%
x.append(5)
print(x)
# Out:
# [1, 2, 3, 5]

# %%
x.pop()
# Out:
# 5

# %%
y = ["a", "b", "c"]

# %%
y.sort()
print(y)
# Out:
# ['a', 'b', 'c']

# %%
y.reverse()
print(y)
# Out:
# ['c', 'b', 'a']

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
list3 = [7, 8, 9]

# %%
list4 = [list1, list2, list3]

# %%
list4
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# ## 1.6. Dicionários

# %% [markdown]
# ## 1.7. Tuplas
