# %% [markdown]
# # Exercícios

# %% [markdown]
# **Link para o dataset:**  https://www.kaggle.com/datasets/matheusfreitag/gas-prices-in-brazil

# %% [markdown]
# ### Neste projeto, trabalharemos com dois arquivos csvs separados, contendo informações sobre o preço da gasolina no Brasil

# %% [markdown]
# ### 1. Carregue os conjuntos de dados "gasolina_2000+.csv" e "gasolina_2010+.csv" em dois DataFrames diferentes e combine-os em um único DataFrame

# %%
import pandas as pd
dataframe = pd.read_csv("2004-2021.tsv", sep="\t")
dataframe.head(3)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
# 2                0.419                     0.070                     0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                    0.9666                         0.133
# 1                      1.05                         0.115
# 2                     1.161                         0.098

# %% [markdown]
# ### 2. Investigue as colunas e entenda o conjunto de dados usando o head() e o info()

# %%
dataframe.shape
# Out:
# (120823, 18)

# %%
dataframe.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                         0.133
# 1                         0.115
# 2                         0.098
# 3                         0.143
# 4                         0.082

# %%
dataframe.tail(3)
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO     ESTADO          PRODUTO  \
# 120820   2021-04-25  2021-05-01   SUDESTE  SAO PAULO  OLEO DIESEL S10
# 120821   2021-04-25  2021-05-01  NORDESTE    SERGIPE  OLEO DIESEL S10
# 120822   2021-04-25  2021-05-01     NORTE  TOCANTINS  OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 120820                           886              R$/l                4.246
# 120821                            33              R$/l                4.464
# 120822                            18              R$/l                4.352
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 120820                  0.216                 3.769                 5.199
# 120821                  0.205                 4.190                 4.699
# 120822                  0.156                 4.199                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 120820             -99999.0                     0.051
# 120821             -99999.0                     0.046
# 120822             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 120820                 -99999.0                   -99999.0
# 120821                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 120820                      -99999.0
# 120821                      -99999.0
# 120822                      -99999.0

# %%
dataframe.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  str
#  1   DATA FINAL                     120823 non-null  str
#  2   REGIÃO                         120823 non-null  str
#  3   ESTADO                         120823 non-null  str
#  4   PRODUTO                        120823 non-null  str
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  str
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           120823 non-null  str
#  12  COEF DE VARIAÇÃO REVENDA       120823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       120823 non-null  str
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     120823 non-null  str
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      120823 non-null  str
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      120823 non-null  str
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  120823 non-null  str
# dtypes: float64(5), int64(1), str(12)
# memory usage: 16.6 MB

# %% [markdown]
# ### 3. Selecione a terceira entrada da coluna DATA INICIAL e verifique seu tipo

# %%
type(dataframe["DATA INICIAL"][2])
# Out:
# str

# %% [markdown]
# ### 4. Você deve ter percebido que as colunas DATA INICIAL e DATA FINAL estão formatadas como string. Utilizando o método pd.to_datetime(), converta ambas as colunas para Timestamp / Datetime

# %%
pd.to_datetime(dataframe["DATA INICIAL"])
# Out:
# 0        2004-05-09
# 1        2004-05-09
# 2        2004-05-09
# 3        2004-05-09
# 4        2004-05-09
#             ...
# 120818   2021-04-25
# 120819   2021-04-25
# 120820   2021-04-25
# 120821   2021-04-25
# 120822   2021-04-25
# Name: DATA INICIAL, Length: 120823, dtype: datetime64[us]

# %%
dataframe["DATA INICIAL"] = pd.to_datetime(dataframe["DATA INICIAL"])
dataframe["DATA FINAL"] = pd.to_datetime(dataframe["DATA FINAL"])

# %% [markdown]
# ### 5. Crie uma nova coluna para representar o mês e o ano (mm-aaaa), utilizando a coluna DATA FINAL como referência.

# %%
dataframe["MES E ANO"] = dataframe["DATA FINAL"].dt.strftime("%m-%Y")

# %%
dataframe.head(3)
# Out:
#   DATA INICIAL DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09 2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   2004-05-09 2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
# 2                0.419                     0.070                     0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MES E ANO
# 0                    0.9666                         0.133   05-2004
# 1                      1.05                         0.115   05-2004
# 2                     1.161                         0.098   05-2004

# %%
type(dataframe["MES E ANO"][0])
# Out:
# str

# %% [markdown]
# ### 6. Utilizando o value_counts(), liste todos os tipos de produtos contidos na base de dados.

# %%
dataframe["PRODUTO"].value_counts()
# Out:
# PRODUTO
# GASOLINA COMUM        23570
# GLP                   23561
# ETANOL HIDRATADO      23440
# ÓLEO DIESEL           21194
# GNV                   14469
# ÓLEO DIESEL S10        9113
# OLEO DIESEL S10        2376
# OLEO DIESEL            2351
# GASOLINA ADITIVADA      749
# Name: count, dtype: int64

# %% [markdown]
# ### 7. Filtre o dataframe para obter apenas os dados da 'GASOLINA COMUM'. Grave em uma nova variável.

# %%
df2 = dataframe[dataframe["PRODUTO"] == "GASOLINA COMUM"]

# %%
df2.shape
# Out:
# (23570, 19)

# %%
df2.head()
# Out:
#       DATA INICIAL DATA FINAL        REGIÃO              ESTADO  \
# 12064   2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 12065   2004-05-09 2004-05-15  CENTRO OESTE               GOIAS
# 12066   2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO
# 12067   2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 12068   2004-05-09 2004-05-15      NORDESTE             ALAGOAS
#
#               PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 12064  GASOLINA COMUM                           128              R$/l
# 12065  GASOLINA COMUM                           395              R$/l
# 12066  GASOLINA COMUM                           194              R$/l
# 12067  GASOLINA COMUM                           166              R$/l
# 12068  GASOLINA COMUM                           106              R$/l
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 12064                2.029                  0.007                  1.99
# 12065                2.025                  0.062                  1.85
# 12066                2.358                  0.066                  2.00
# 12067                2.120                  0.075                  1.97
# 12068                2.090                  0.034                  2.00
#
#        PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 12064                 2.070                0.318                     0.003
# 12065                 2.220                0.296                     0.031
# 12066                 2.540                0.472                     0.028
# 12067                 2.440                0.325                     0.035
# 12068                 2.159                 0.35                     0.016
#
#       PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12064                    1.711                       0.02
# 12065                    1.729                      0.036
# 12066                    1.886                      0.068
# 12067                    1.795                      0.033
# 12068                     1.74                      0.042
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12064                     1.651                    1.7427
# 12065                    1.6643                     1.915
# 12066                      1.75                    2.0713
# 12067                   1.70701                    1.9703
# 12068                    1.6789                     1.918
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO MES E ANO
# 12064                         0.012   05-2004
# 12065                         0.021   05-2004
# 12066                         0.036   05-2004
# 12067                         0.018   05-2004
# 12068                         0.024   05-2004

# %% [markdown]
# ### 8. Qual o preço médio de revenda da gasolina em agosto de 2008?

# %%
df2[df2["MES E ANO"] == "08-2008"]["PREÇO MÉDIO REVENDA"].mean()
# Out:
# np.float64(2.6012444444444442)

# %% [markdown]
# ### 9. Qual o preço médio de revenda da gasolina em maio de 2014 em São Paulo?

# %%
df2[(df2["MES E ANO"] == "05-2014") & (df2["ESTADO"] == "SAO PAULO")]["PREÇO MÉDIO REVENDA"].mean()
# Out:
# np.float64(2.8822)

# %% [markdown]
# ### 10. Você conseguiria descobrir em qual(quais) estado(s) a gasolina ultrapassou a barreira dos R$:5,00? E quando isso ocorreu?

# %%
df2[df2["PREÇO MÉDIO REVENDA"] > 5][["ESTADO", "MES E ANO", "PREÇO MÉDIO REVENDA"]]
# Out:
#                 ESTADO MES E ANO  PREÇO MÉDIO REVENDA
# 98201             ACRE   05-2018                5.053
# 98347             ACRE   06-2018                5.035
# 98493             ACRE   06-2018                5.038
# 98511   RIO DE JANEIRO   06-2018                5.016
# 98646             ACRE   06-2018                5.031
# ...                ...       ...                  ...
# 120721         RORAIMA   05-2021                5.364
# 120722  SANTA CATARINA   05-2021                5.051
# 120723       SAO PAULO   05-2021                5.265
# 120724         SERGIPE   05-2021                5.586
# 120725       TOCANTINS   05-2021                5.751
#
# [353 rows x 3 columns]

# %% [markdown]
# ### 11. Qual a média de preço dos estados da região sul em 2012?

# %%
df_aux = df2[df2["DATA FINAL"].apply(lambda x: x.year) == 2012]
df_aux[df_aux["REGIÃO"] == "SUL"]["PREÇO MÉDIO REVENDA"].mean()
# Out:
# np.float64(2.7214423076923073)

# %%
df2[(df2["DATA FINAL"].apply(lambda x: x.year) == 2012) & (df_aux["REGIÃO"] == "SUL") ]["PREÇO MÉDIO REVENDA"].mean()
# Out:
# np.float64(2.7214423076923073)

# %% [markdown]
# ### 12. Você conseguiria obter uma tabela contendo a variação percentual ano a ano para o estado do Rio de Janeiro?

# %%
dataframe.head(2)
# Out:
#   DATA INICIAL DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09 2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MES E ANO
# 0                    0.9666                         0.133   05-2004
# 1                      1.05                         0.115   05-2004

# %%
dataframe["MES"] = dataframe["DATA FINAL"].apply(lambda x: x.month)

# %%
df_rio = dataframe[dataframe["ESTADO"] == "RIO DE JANEIRO"]

# %%
df_month_rio = df_rio.groupby("MES E ANO")[["PREÇO MÉDIO REVENDA", "MES"]].last()

# %%
(df_month_rio[df_month_rio["MES"] == 12] / df_month_rio[df_month_rio["MES"] == 12].shift(1) -1) * 100
# Out:
#            PREÇO MÉDIO REVENDA  MES
# MES E ANO
# 12-2004                    NaN  NaN
# 12-2005              12.338063  0.0
# 12-2006              -0.878638  0.0
# 12-2007               0.720222  0.0
# 12-2008              14.466447  0.0
# 12-2009              -4.949543  0.0
# 12-2010               0.202224  0.0
# 12-2011               1.261352  0.0
# 12-2012               5.630294  0.0
# 12-2013             -21.084906  0.0
# 12-2014               7.770472  0.0
# 12-2015              17.304493  0.0
# 12-2016              -2.269504  0.0
# 12-2017               9.869376  0.0
# 12-2018              35.358873  0.0
# 12-2019              24.951204  0.0
# 12-2020              -1.483989  0.0
