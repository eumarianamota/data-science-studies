# %% [markdown]
# # Transformação e agrupamentos simples

# %%
import pandas as pd

# %%
df = pd.read_csv("2004-2021.tsv", sep="\t")

# %% [markdown]
# ### 1. Conversão de Datas: Converta a coluna "DATA FINAL" para o formato datetime do Pandas.

# %%
df["DATA FINAL"] = pd.to_datetime(df["DATA FINAL"])

# %%
type(df["DATA FINAL"][0])
# Out:
# pandas.Timestamp

# %% [markdown]
# ### 2. Extração de Ano: Crie uma nova coluna chamada "ANO" extraída apenas da "DATA FINAL".

# %%
df["ANO"] = df["DATA FINAL"].apply(lambda x: x.year)

# %%
df[["DATA FINAL", "ANO"]].head()
# Out:
#   DATA FINAL   ANO
# 0 2004-05-15  2004
# 1 2004-05-15  2004
# 2 2004-05-15  2004
# 3 2004-05-15  2004
# 4 2004-05-15  2004

# %% [markdown]
# ### 3. Renomeação: Altere o nome das colunas "REGIÃO" para "REGION" e "ESTADO" para "STATE" (apenas para praticar a função de renomear).

# %%
df.rename(columns={"REGIÃO": "REGION", "ESTADO": "STATE"}).head(1)
# Out:
#   DATA INICIAL DATA FINAL        REGION             STATE           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                  1.35
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO   ANO
# 0                    0.9666                         0.133  2004

# %% [markdown]
# ### 4. Média por Região: Qual é o preço médio de revenda da gasolina para cada uma das 5 regiões do Brasil? (Dica: use groupby).

# %%
df.groupby("REGIÃO")["PREÇO MÉDIO REVENDA"].mean()
# Out:
# REGIÃO
# CENTRO OESTE    12.440722
# NORDESTE        10.663357
# NORTE           13.411680
# SUDESTE         10.217240
# SUL             10.562091
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %% [markdown]
# ### 5. Volume de Dados: Conte quantos registros existem para cada estado na base de dados.

# %%
df.groupby("REGIÃO")["ESTADO"].value_counts()
# Out:
# REGIÃO        ESTADO
# CENTRO OESTE  MATO GROSSO DO SUL     4793
#               MATO GROSSO            4566
#               GOIAS                  4134
#               DISTRITO FEDERAL       3956
# NORDESTE      BAHIA                  4819
#               PARAIBA                4819
#               RIO GRANDE DO NORTE    4818
#               CEARA                  4813
#               PERNAMBUCO             4813
#               ALAGOAS                4806
#               SERGIPE                4795
#               PIAUI                  4017
#               MARANHAO               3971
# NORTE         AMAZONAS               4414
#               PARA                   3955
#               TOCANTINS              3953
#               RONDONIA               3950
#               ACRE                   3948
#               RORAIMA                3938
#               AMAPA                  3831
# SUDESTE       RIO DE JANEIRO         4819
#               SAO PAULO              4819
#               MINAS GERAIS           4817
#               ESPIRITO SANTO         4815
# SUL           RIO GRANDE DO SUL      4819
#               SANTA CATARINA         4818
#               PARANA                 4807
# Name: count, dtype: int64

# %% [markdown]
# ### 6. Unidades de Medida: Identifique quais produtos são vendidos em "R/l" e quais são vendidos em "R$13kg".

# %%
df[df["UNIDADE DE MEDIDA"].isin(["R$/13Kg"])]["PRODUTO"].value_counts()
# Out:
# PRODUTO
# GLP    23561
# Name: count, dtype: int64

# %%
df[df["UNIDADE DE MEDIDA"].isin(["R$/l"])]["PRODUTO"].value_counts()
# Out:
# PRODUTO
# GASOLINA COMUM        23570
# ETANOL HIDRATADO      23440
# ÓLEO DIESEL           21194
# ÓLEO DIESEL S10        9113
# OLEO DIESEL S10        2376
# OLEO DIESEL            2351
# GASOLINA ADITIVADA      749
# Name: count, dtype: int64

# %% [markdown]
# ### 7.
 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 110732                      2.75                    3.1769
# 110735                    2.4854                    3.4635
# 110736                    3.0331                     3.547
# 110740                    3.2279                    3.4984
# 110745                       2.6                    3.5546
# ...                          ...                       ...
# 117616                  -99999.0                  -99999.0
# 117618                  -99999.0                  -99999.0
# 117619                  -99999.0                  -99999.0
# 117621                  -99999.0                  -99999.0
# 117627                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO   ANO
# 110732                         0.042  2020
# 110735                         0.045  2020
# 110736                         0.038  2020
# 110740                         0.032  2020
# 110745                         0.071  2020
# ...                              ...   ...
# 117616                      -99999.0  2020
# 117618                      -99999.0  2020
# 117619                      -99999.0  2020
# 117621                      -99999.0  2020
# 117627                      -99999.0  2020
#
# [2361 rows x 19 columns]

# %% [markdown]
# ### 8. Cálculo de Margem: Crie uma coluna chamada "DIFERENÇA_PREÇO" que seja a subtração entre o "PREÇO MÁXIMO REVENDA" e o "PREÇO MÍNIMO REVENDA".

# %%
df["DIFERENÇA PREÇO"] = df["PREÇO MÁXIMO REVENDA"] - df["PREÇO MÍNIMO REVENDA"]

# %%
df.head()
# Out:
#   DATA INICIAL DATA FINAL        REGIÃO              ESTADO           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09 2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2   2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 3   2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 4   2004-05-09 2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
# 3                           162              R$/l                1.262
# 4                           103              R$/l                1.181
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
# 3                  0.070                  1.09                 1.509
# 4                  0.078                  1.05                 1.400
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
# 2                0.419                     0.070                     0.97
# 3                0.432                     0.055                     0.83
# 4                 0.24                     0.066                    0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO   ANO  \
# 0                    0.9666                         0.133  2004
# 1                      1.05                         0.115  2004
# 2                     1.161                         0.098  2004
# 3                   1.22242                         0.143  2004
# 4                    1.0317                         0.082  2004
#
#    DIFERENÇA PREÇO
# 0            0.160
# 1            0.559
# 2            0.580
# 3            0.419
# 4            0.350

# %% [markdown]
# ### 9. Estatística Descritiva: Utilize um único método do Pandas para exibir um resumo estatístico (média, desvio padrão, quartis) apenas das colunas de preço do estado de São Paulo.

# %%
df[df["ESTADO"] == "SAO PAULO"][["PREÇO MÉDIO REVENDA", "PREÇO MÍNIMO REVENDA", "PREÇO MÁXIMO REVENDA"]].describe()
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA
# count          4819.000000           4819.000000           4819.000000
# mean             10.031501              7.788166             12.745681
# std              17.381130             12.966484             22.507237
# min               0.766000              0.590000              1.099000
# 25%               1.864000              1.599000              2.399000
# 50%               2.554000              2.199000              2.999000
# 75%               3.607000              3.179000              4.416000
# max              85.340000             68.000000            110.000000

# %% [markdown]
# ### 10. Ordenação: Mostre os 10 registros com os preços de revenda mais baratos do Brasil, ordenando o DataFrame.

# %%
df["PREÇO MÉDIO REVENDA"].nsmallest(10)
# Out:
# 50     0.766
# 23     0.768
# 77     0.823
# 104    0.887
# 131    0.894
# 158    0.898
# 212    0.899
# 239    0.902
# 185    0.904
# 266    0.907
# Name: PREÇO MÉDIO REVENDA, dtype: float64
