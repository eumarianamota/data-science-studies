# %% [markdown]
# # Exploração e filtros básicos

# %% [markdown]
# ### 1. Carga e Inspeção: Carregue o arquivo e exiba as 10 primeiras linhas para entender a estrutura dos dados.

# %%
import pandas as pd

# %%
df = pd.read_csv("2004-2021.tsv", sep="\t")

# %%
df.head(10)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# ...

# %% [markdown]
# ### 2. Dimensões: Quantas linhas e quantas colunas esse conjunto de dados possui no total?

# %%
df.shape
# Out:
# (120823, 18)

# %% [markdown]
# ### 3. Dicionário de Dados: Liste o nome de todas as colunas e verifique quais delas são do tipo numérico e quais são objetos (strings).

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  str
#  1   DATA FINAL                     120823 non-null  str
#  2   REGIÃO                         120823 non-null  str
#  3   ESTADO                         120823 non-null  str
#  4   PRODUTO                        120823 non-null  str
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  str
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           120823 non-null  str
# ...

# %% [markdown]
# ### 4. Extremos de Preço: Qual foi o maior preço médio de revenda registrado em toda a história do dataset? E o menor?

# %%
df["PREÇO MÉDIO REVENDA"].max()
# Out:
# np.float64(107.5)

# %%
df["PREÇO MÉDIO REVENDA"].min()
# Out:
# np.float64(0.7659999999999999)

# %% [markdown]
# ### 5. Filtro por Estado: Crie um novo DataFrame contendo apenas os dados do estado do Piauí (valorizando sua localização na UESPI!).

# %%
df_pi = df[df["ESTADO"] == "PIAUI"]

# %%
df_pi.head(5)
# Out:
#     DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 10    2004-05-09  2004-05-15  NORDESTE  PIAUI  ETANOL HIDRATADO
# 37    2004-05-16  2004-05-22  NORDESTE  PIAUI  ETANOL HIDRATADO
# 64    2004-05-23  2004-05-29  NORDESTE  PIAUI  ETANOL HIDRATADO
# 91    2004-05-30  2004-06-05  NORDESTE  PIAUI  ETANOL HIDRATADO
# 118   2004-06-06  2004-06-12  NORDESTE  PIAUI  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 10                             89              R$/l                1.573
# 37                             93              R$/l                1.571
# 64                             91              R$/l                1.569
# 91                             94              R$/l                1.564
# 118                            94              R$/l                1.604
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %% [markdown]
# ### 6. Contagem de Produtos: Quais são os diferentes tipos de produtos (combustíveis) listados? Use um método que mostre a lista sem repetições.

# %%
df["PRODUTO"].value_counts()
# Out:
# PRODUTO
# GASOLINA COMUM        23570
# GLP                   23561
# ETANOL HIDRATADO      23440
# ÓLEO DIESEL           21194
# GNV                   14469
# ÓLEO DIESEL S10        9113
# OLEO DIESEL S10        2376
# OLEO DIESEL            2351
# GASOLINA ADITIVADA      749
# Name: count, dtype: int64

# %% [markdown]
# ### 7. Filtro de Produto: Selecione apenas as linhas onde o produto é "GLP" (Gás de Cozinha) e exiba as 5 primeiras entradas.

# %%
df[df["PRODUTO"] == "GLP"].head(5)
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO              ESTADO PRODUTO  \
# 24132   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL     GLP
# 24133   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS     GLP
# 24134   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO     GLP
# 24135   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL     GLP
# 24136   2004-05-09  2004-05-15      NORDESTE             ALAGOAS     GLP
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 24132                            44           R$/13Kg               33.989
# 24133                           372           R$/13Kg               30.335
# 24134                            97           R$/13Kg               38.568
# 24135                           109           R$/13Kg               33.388
# 24136                            22           R$/13Kg               32.391
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %% [markdown]
# ### 8. Análise de Postos: Qual é a média da coluna "NÚMERO DE POSTOS PESQUISADOS" em todo o Brasil?

# %%
df["NÚMERO DE POSTOS PESQUISADOS"].mean()
# Out:
# np.float64(221.06646085596284)

# %% [markdown]
# ### 9. Busca Específica: Encontre todas as ocorrências onde o "PREÇO MÉDIO REVENDA" foi maior que R$ 6,00.

# %%
df[df["PREÇO MÉDIO REVENDA"] > 6]
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO PRODUTO  \
# 24132    2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL     GLP
# 24133    2004-05-09  2004-05-15  CENTRO OESTE               GOIAS     GLP
# 24134    2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO     GLP
# 24135    2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL     GLP
# 24136    2004-05-09  2004-05-15      NORDESTE             ALAGOAS     GLP
# ...             ...         ...           ...                 ...     ...
# 120748   2021-04-25  2021-05-01         NORTE             RORAIMA     GLP
# 120749   2021-04-25  2021-05-01           SUL      SANTA CATARINA     GLP
# 120750   2021-04-25  2021-05-01       SUDESTE           SAO PAULO     GLP
# 120751   2021-04-25  2021-05-01      NORDESTE             SERGIPE     GLP
# 120752   2021-04-25  2021-05-01         NORTE           TOCANTINS     GLP
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# ### 10. Verificação de Nulos: Verifique se existe algum valor ausente (NaN) no DataFrame e em qual coluna ele se encontra.

# %%
df.isnull().sum()
# Out:
# DATA INICIAL                     0
# DATA FINAL                       0
# REGIÃO                           0
# ESTADO                           0
# PRODUTO                          0
# NÚMERO DE POSTOS PESQUISADOS     0
# UNIDADE DE MEDIDA                0
# PREÇO MÉDIO REVENDA              0
# DESVIO PADRÃO REVENDA            0
# PREÇO MÍNIMO REVENDA             0
# PREÇO MÁXIMO REVENDA             0
# MARGEM MÉDIA REVENDA             0
# COEF DE VARIAÇÃO REVENDA         0
# PREÇO MÉDIO DISTRIBUIÇÃO         0
# DESVIO PADRÃO DISTRIBUIÇÃO       0
# PREÇO MÍNIMO DISTRIBUIÇÃO        0
# PREÇO MÁXIMO DISTRIBUIÇÃO        0
# COEF DE VARIAÇÃO DISTRIBUIÇÃO    0
# dtype: int64
